# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np  

X = np.array([
    [820, 420, 790, 400],  # strong left
    [410, 850, 390, 830],  # strong right
    [900, 920, 400, 420],  # strong top
    [400, 420, 900, 910],  # strong bottom
    [750, 760, 740, 755],  # balanced
])

# Target outputs (steps to rotate)
Y = np.array([
    [-15,  5],   # rotate left, small up
    [ 20,  5],   # rotate right, small up
    [  0, 25],   # tilt up
    [  0,-20],   # tilt down
    [  0,  0],   # stable
])

## First y (left)
# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y[:, 0], test_size=0.2)
print(y_train)
# Create and train the model
model = RandomForestRegressor()
model.fit(X_train, y_train)
print(model)
# Check accuracy
print(model.score(X_test, y_test))

## Second y (right)
# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y[:, 1], test_size=0.2)
print(y_train)
# Create and train the model
model = RandomForestRegressor()
model.fit(X_train, y_train)
print(model)
# Check accuracy
print(model.score(X_test, y_test))
# Out:
# [ 20   0   0 -15]
# RandomForestRegressor()
# nan
# [ 5  0 25  5]
# RandomForestRegressor()
# nan
# c:\Users\twohi\anaconda3\envs\MDM3\Lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\twohi\anaconda3\envs\MDM3\Lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
